# %% [markdown]
# **How to read a data frame**

# %% [markdown]
# - location
# - file name
# - extention
# - I want to read data1
# - location is not required beacuse python file and data file both are at same location
# - file name: data1
# - extention: csv

# %%
import pandas as pd
pd.read_csv('data1.csv')
# Out:
#      Names  Age     City
# 0  Avinash   30      blr
# 1    Akash   35  chennai
# 2     Anvi   40   Mumbai

# %%
pd.read_excel('data2.xlsx')
# Out:
#      Names  Age     City
# 0  Avinash   30      blr
# 1    Akash   35  chennai
# 2     Anvi   40   Mumbai

# %%
visa_df=pd.read_csv(r"C:\Users\HP\Documents\NareshIT\Data Files\Visadataset - Visadataset (1).csv")

# %%
visa_df
# Out:
#          case_id continent education_of_employee  ... unit_of_wage full_time_position  case_status
# 0         EZYV01      Asia           High School  ...         Hour                  Y       Denied
# 1         EZYV02      Asia              Master's  ...         Year                  Y    Certified
# 2         EZYV03      Asia            Bachelor's  ...         Year                  Y       Denied
# 3         EZYV04      Asia            Bachelor's  ...         Year                  Y       Denied
# 4         EZYV05    Africa              Master's  ...         Year                  Y    Certified
# ...          ...       ...                   ...  ...          ...                ...          ...
# 25475  EZYV25476      Asia            Bachelor's  ...         Year                  Y    Certified
# 25476  EZYV25477      Asia           High School  ...         Year                  Y    Certified
# ...

# %%
bank_df=pd.read_csv(r"C:\Users\HP\Documents\NareshIT\Data Files\bank - bank.csv")
bank_df
# Out:
#       age            job  marital  education default  balance  ... duration campaign pdays  previous poutcome   y
# 0      30     unemployed  married    primary      no     1787  ...       79        1    -1         0  unknown  no
# 1      33       services  married  secondary      no     4789  ...      220        1   339         4  failure  no
# 2      35     management   single   tertiary      no     1350  ...      185        1   330         1  failure  no
# 3      30     management  married   tertiary      no     1476  ...      199        4    -1         0  unknown  no
# 4      59    blue-collar  married  secondary      no        0  ...      226        1    -1         0  unknown  no
# ...   ...            ...      ...        ...     ...      ...  ...      ...      ...   ...       ...      ...  ..
# 4516   33       services  married  secondary      no     -333  ...      329        5    -1         0  unknown  no
# ...

# %% [markdown]
# **Create data frame using dictionary**

# %%
name=['Avinash','Aakash','Aadhya']
age=[25,30,35]
pd.DataFrame(zip(name,age),columns=['Names','Ages'])
# Out:
#      Names  Ages
# 0  Avinash    25
# 1   Aakash    30
# 2   Aadhya    35

# %%
dict1={'Names':['Avinash','Aakash','Aadhya'],
       'Ages':[25,30,35]}
dict1
# Out:
# {'Names': ['Avinash', 'Aakash', 'Aadhya'], 'Ages': [25, 30, 35]}

# %%
pd.DataFrame(dict1)
# keys becomes columns
# values becomes rows
#
# Out:
#      Names  Ages
# 0  Avinash    25
# 1   Aakash    30
# 2   Aadhya    35

# %%
dict2={'Names':'Avinash',
       'Ages':25,
       'City':'Hyd'}
pd.DataFrame(dict2,index=[1,2,3])
# Out:
#      Names  Ages City
# 1  Avinash    25  Hyd
# 2  Avinash    25  Hyd
# 3  Avinash    25  Hyd
